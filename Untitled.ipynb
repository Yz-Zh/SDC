# %%
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
x=["rental","type","11","12","13","14","15","16","17","18","19","10"]
y=[3.92,3.97,3.58,4.05,4.33,3.58,3.49,3.95,3.89,3.04,3.16,2.48]

plt.bar(x,y,label="Sequential",alpha=0.5 )
plt.bar(x=3,height=0.00004,color="r",label="non-sequential",alpha=0.2 )
plt.plot(x,y,color="black",alpha=1)
plt.ylim((2.25,4.5))
# Out:
# (2.25, 4.5)
